# %% [markdown]
# # A little bit of numpy

# %%
import pandas as pd

# %%
data = pd.read_csv('../Data/Solubility/E_X')

# %%
data
# Out:
#       nX  nHeavyAtom  nAromAtom  nHBAcc  nHBDon  nRot  nBonds  nAromBond  \
# 0      0           5          0       0       0     2      16          0
# 1      0           5          0       0       0     0      15          0
# 2      0           6          0       0       0     3      19          0
# 3      0           6          0       0       0     2      19          0
# 4      0           6          0       0       0     0      19          0
# ...   ..         ...        ...     ...     ...   ...     ...        ...
# 1286   0          19          0       8       0     9      37          0
# 1287   3          18          6       5       0     6      29          6
# 1288   0          25          0       4       3    12      57          0
# 1289   5          19         12       0       0     2      29         12
# 1290   8          18          0       0       0     0      26          0
#
#       nBondsO  nBondsS  nBondsD  nBondsT  Solubility
# ...

# %%
import numpy as np

# %%
data = np.array(data)

# %%
data
# Out:
# array([[ 0.  ,  5.  ,  0.  , ...,  0.  ,  0.  , -3.18],
#        [ 0.  ,  5.  ,  0.  , ...,  0.  ,  0.  , -2.64],
#        [ 0.  ,  6.  ,  0.  , ...,  0.  ,  0.  , -3.84],
#        ...,
#        [ 0.  , 25.  ,  0.  , ...,  4.  ,  0.  , -2.47],
#        [ 5.  , 19.  , 12.  , ...,  0.  ,  0.  , -7.15],
#        [ 8.  , 18.  ,  0.  , ...,  1.  ,  0.  , -6.86]])

# %%
v1 = np.array([1,-2,3,4])

# %%
v2 = np.array([4,5,-3,2])

# %%
v1
# Out:
# array([ 1, -2,  3,  4])

# %%
type(v1)
# Out:
# numpy.ndarray

# %%
v1.shape
# Out:
# (4,)

# %%
v1 + v2
# Out:
# array([5, 3, 0, 6])

# %%
v1 * v2
# Out:
# array([  4, -10,  -9,   8])

# %%
v1 + 1
# Out:
# array([ 2, -1,  4,  5])

# %%
v1 ** 2
# Out:
# array([ 1,  4,  9, 16])

# %%
np.abs(v1)
# Out:
# array([1, 2, 3, 4])

# %%
v1.sum()
# Out:
# 6

# %%
v1.sum() / len(v1)
# Out:
# 1.5

# %%
v1.mean()
# Out:
# 1.5

# %%
v1.std()
# Out:
# 2.29128784747792

# %%
np.dot(v1,v2)
# Out:
# -7

# %%
v1
# Out:
# array([ 1, -2,  3,  4])

# %%
v1[:2]
# Out:
# array([ 1, -2])

# %%
v1[2:]
# Out:
# array([3, 4])

# %%
v1[-2:]
# Out:
# array([3, 4])

# %%
np.concatenate([v1,v2])
# Out:
# array([ 1, -2,  3,  4,  4,  5, -3,  2])

# %%
np.stack([v1,v2])
# Out:
# array([[ 1, -2,  3,  4],
#        [ 4,  5, -3,  2]])

# %%
x = np.linspace(-2,2,100)

# %%
x
# Out:
# array([-2.        , -1.95959596, -1.91919192, -1.87878788, -1.83838384,
#        -1.7979798 , -1.75757576, -1.71717172, -1.67676768, -1.63636364,
#        -1.5959596 , -1.55555556, -1.51515152, -1.47474747, -1.43434343,
#        -1.39393939, -1.35353535, -1.31313131, -1.27272727, -1.23232323,
#        -1.19191919, -1.15151515, -1.11111111, -1.07070707, -1.03030303,
#        -0.98989899, -0.94949495, -0.90909091, -0.86868687, -0.82828283,
#        -0.78787879, -0.74747475, -0.70707071, -0.66666667, -0.62626263,
#        -0.58585859, -0.54545455, -0.50505051, -0.46464646, -0.42424242,
#        -0.38383838, -0.34343434, -0.3030303 , -0.26262626, -0.22222222,
#        -0.18181818, -0.14141414, -0.1010101 , -0.06060606, -0.02020202,
#         0.02020202,  0.06060606,  0.1010101 ,  0.14141414,  0.18181818,
#         0.22222222,  0.26262626,  0.3030303 ,  0.34343434,  0.38383838,
#         0.42424242,  0.46464646,  0.50505051,  0.54545455,  0.58585859,
# ...

# %%
np.sin(x)
# Out:
# array([-0.90929743, -0.92536476, -0.93992165, -0.95294434, -0.96441158,
#        -0.97430464, -0.98260737, -0.98930624, -0.99439029, -0.99785123,
#        -0.99968342, -0.99988386, -0.99845223, -0.99539085, -0.99070474,
#        -0.98440153, -0.97649152, -0.96698762, -0.95590534, -0.94326277,
#        -0.92908054, -0.91338181, -0.8961922 , -0.87753977, -0.85745496,
#        -0.83597055, -0.81312162, -0.78894546, -0.76348154, -0.73677141,
#        -0.70885867, -0.67978889, -0.64960951, -0.6183698 , -0.58612075,
#        -0.55291499, -0.51880673, -0.48385164, -0.44810678, -0.41163048,
#        -0.3744823 , -0.33672286, -0.2984138 , -0.25961766, -0.22039774,
#        -0.18081808, -0.14094328, -0.10083842, -0.06056897, -0.02020065,
#         0.02020065,  0.06056897,  0.10083842,  0.14094328,  0.18081808,
#         0.22039774,  0.25961766,  0.2984138 ,  0.33672286,  0.3744823 ,
#         0.41163048,  0.44810678,  0.48385164,  0.51880673,  0.55291499,
# ...

# %%
v1.reshape(4,1)
# Out:
# array([[ 1],
#        [-2],
#        [ 3],
#        [ 4]])

# %%
v1.reshape(-1,1)
# Out:
# array([[ 1],
#        [-2],
#        [ 3],
#        [ 4]])

# %% [markdown]
# # ML

# %%
def f(x):
    return np.sin(x**3 + x**2)

# %%
x = x.reshape(-1,1)

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(x,f(x),color='r')

# %%
data_x = x[::7].reshape(-1, 1)

# %%
data_y = f(data_x)

# %%
plt.plot(x,f(x),color='r')
plt.scatter(data_x,data_y)

# %% [markdown]
# True risk of $h$:
# $$
# \mathcal{L}(h) = \int_{-\infty}^{\infty} |h(x) - f(x)| \text{d}x
# $$ or,
# $$
# \mathcal{L}(h) = \int_{-\infty}^{\infty} (h(x) - f(x))^2 \text{d}x
# $$

# %% [markdown]
# Empirical risk:

# %%
def mse(y,y_pred):
    return ((y - y_pred)**2).mean()

# %%
from sklearn.linear_model import LinearRegression as LR

# %%
model = LR()

# %% [markdown]
# Two stages of training.

# %%
model.fit(data_x,data_y) # 'Trainign time'
# Out:
# LinearRegression()

# %%
y_pred = model.predict(x) # 'Test time'

# %%
plt.scatter(data_x,data_y)
plt.plot(x,y_pred,color='g')

# %% [markdown]
# This is undefitting

# %%
mse(f(x),y_pred)
# Out:
# 0.2918188294868988

# %% [markdown]
# Combine feature engineering with linear regression.

# %%
from sklearn.preprocessing import PolynomialFeatures as PF

# %%
def experiment(d):
    
    poly = PF(d)
    poly.fit(data_x)
    model = LR()
    model.fit(poly.transform(data_x),data_y)
    y_pred = model.predict(poly.transform(x))
    
    plt.scatter(data_x,data_y)
    plt.plot(x,y_pred,color='g')
    plt.plot(x,f(x),'r')
    plt.ylim(-1,1)
    plt.title(mse(f(x),y_pred))
    plt.show()

# %%
experiment(2)

# %%
for i in range(30):
    experiment(i)

# %%
experiment(60)

# %% [markdown]
# ## Hoeffding Inequality and Generalization Bounds

# %% [markdown]
# **Hoeffding inequality**:<br>
# Let $\theta_1, \theta_2, \cdots, \theta_n$ ve a sequence of i.i.d. random variables such that
# <ul>
# <li> $E[\theta_i] = \mu$
# <li> $\Pr[a \leq \theta_i \leq b] = 1$
# </ul>
# then, for any $\epsilon > 0$,
# $$
# \Pr\left[ \left| \frac{1}{n} \sum_{i=1}^n \theta_i - \mu \right| > \epsilon \right] \leq 2 e^{- \frac{2n\epsilon^2}{(b-a)^2}}
# $$

# %% [markdown]
# **Application to learning**:<br>
# For $x_1, ..., x_n$ i.i.d. samples from the feature distribution, take $\theta_i = (h(x_i) - f(x_i))^2$<br>
# Note that $E[\theta_i] = E[(h(x_i) - f(x_i))^2] = \mathcal{L}(h)$<br>
# and $\frac{1}{n} \sum_{i=1}^n \theta_i = \hat{\mathcal{L}}(h)$<br>
# From the Hoeffding inequality and the union bound, we conclude
# $$
# \Pr(| \mathcal{L}(h) - \hat{\mathcal{L}}(h)| > \epsilon) \leq 2|\mathcal{H}|e^{-2n\epsilon^2}
# $$

# %% [markdown]
# **Bias-complexity tradeoff**:<br>
# Let $h$ be an emprirical risk minimizer:
# $$
# \mathcal{L}(h) = min_h \mathcal{L}(h) + (\mathcal{L}(h) - min_h \mathcal{L}(h))
# $$
# $min_h \mathcal{L}(h)$ is called the approximation error. Intuitively, if $\mathcal{H}$ is too small, there is a risk of undefitting since we could be more likely that none of the functions in $\mathcal{H}$ are close to the target function.<br>
# $\mathcal{L}(h) - min_h \mathcal{L}(h)$ is the difference between the true error (or risk) and the empirical risk.
